# %%
import pandas as pd
import numpy as np

# Load the preprocessed data
df = pd.read_csv('../data/processed/preprocessed_churn_data.csv')

# Display all column names
print("All columns in the dataset:")
print("=" * 50)
for i, col in enumerate(df.columns, 1):
    print(f"{i:2d}. {col}")

# Get column information and sample values
print("\nColumn information and sample values:")
print("=" * 50)
for col in df.columns:
    print(f"\nColumn: {col}")
    print(f"Type: {df[col].dtype}")
    print(f"Sample unique values: {df[col].unique()[:5]}")
    print("-" * 30)

# Display basic statistics for numeric columns
print("\nNumeric columns statistics:")
print("=" * 50)
print(df.describe())
# Out:
# All columns in the dataset:
# ==================================================
#  1. visitorid
#  2. ses_rec
#  3. ses_rec_avg
#  4. ses_rec_sd
#  5. ses_rec_cv
#  6. user_rec
#  7. ses_n
#  8. ses_n_r
#  9. int_n
# 10. int_n_r
# 11. tran_n
# 12. tran_n_r
# 13. rev_sum
# 14. rev_sum_r
# 15. major_spend_r
# 16. int_cat_n_avg
# 17. int_itm_n_avg
# 18. ses_mo_avg
# 19. ses_mo_sd
# 20. ses_ho_avg
# 21. ses_ho_sd
# 22. ses_wknd_r
# 23. ses_len_avg
# 24. time_to_int
# 25. time_to_tran
# 26. int_cat1_n
# 27. int_cat2_n
# 28. int_cat3_n
# 29. int_cat4_n
# 30. int_cat5_n
# 31. int_cat6_n
# 32. int_cat7_n
# 33. int_cat8_n
# 34. int_cat9_n
# 35. int_cat10_n
# 36. int_cat11_n
# 37. int_cat12_n
# 38. int_cat13_n
# 39. int_cat15_n
# 40. int_cat16_n
# 41. int_cat17_n
# 42. int_cat18_n
# 43. int_cat19_n
# 44. int_cat20_n
# 45. int_cat21_n
# 46. int_cat22_n
# 47. int_cat23_n
# 48. int_cat24_n
# 49. target_class
# 50. engagement_ratio
# 51. conversion_rate
# 52. avg_items_per_interaction
# 53. session_consistency
# 54. weekend_preference
# 55. category_diversity
# 56. avg_transaction_value
# 57. value_segment
# 58. recency_score
# 59. user_lifetime
# 60. activity_regularity
# 61. peak_hour_activity
# 62. recency_segment
# 63. activity_decline
# 64. low_engagement
# 65. recency_risk
# 66. engagement_risk
# 67. value_risk
# 68. churn_risk_score
# 69. risk_segment
#
# Column information and sample values:
# ==================================================
#
# Column: visitorid
# Type: int64
# Sample unique values: [ 89 251 270 298 474]
# ------------------------------
#
# Column: ses_rec
# Type: float64
# Sample unique values: [ 0.4375 -0.125  -0.3125  0.      0.3125]
# ------------------------------
#
# Column: ses_rec_avg
# Type: float64
# Sample unique values: [ 0.96491228  4.12280702 -0.15087719  0.75438596  1.66666667]
# ------------------------------
#
# Column: ses_rec_sd
# Type: float64
# Sample unique values: [ 0.          0.3         6.9442225  11.5         0.18885258]
# ------------------------------
#
# Column: ses_rec_cv
# Type: float64
# Sample unique values: [ 0.          1.46707147  0.66912314 -0.61025979  0.61025979]
# ------------------------------
#
# Column: user_rec
# Type: float64
# Sample unique values: [ 0.43333333  1.96666667 -0.16666667 -0.06666667  0.56666667]
# ------------------------------
#
# Column: ses_n
# Type: float64
# Sample unique values: [ 0.  9.  2.  1. 17.]
# ------------------------------
#
# Column: ses_n_r
# Type: float64
# Sample unique values: [-0.37362635 -0.6352941   4.08163283 -0.07142854 -0.41860463]
# ------------------------------
#
# Column: int_n
# Type: float64
# Sample unique values: [ 0.   -0.25  2.5   0.25  0.75]
# ------------------------------
#
# Column: int_n_r
# Type: float64
# Sample unique values: [ 0.25      -0.25      -0.0681819  0.75       2.       ]
# ------------------------------
#
# Column: tran_n
# Type: float64
# Sample unique values: [0. 1. 2.]
# ------------------------------
#
# Column: tran_n_r
# Type: float64
# Sample unique values: [0.         0.33333334 0.5        0.09090909 0.14285715]
# ------------------------------
#
# Column: rev_sum
# Type: float64
# Sample unique values: [    0. 41400. 47520. 43080. 29400.]
# ------------------------------
#
# Column: rev_sum_r
# Type: float64
# Sample unique values: [    0.     13800.     15840.     21540.      2672.7273]
# ------------------------------
#
# Column: major_spend_r
# Type: float64
# Sample unique values: [0.         0.33333334 0.5        0.09090909 0.14285715]
# ------------------------------
#
# Column: int_cat_n_avg
# Type: float64
# Sample unique values: [0.        0.5       0.3571428 0.2       0.0909091]
# ------------------------------
#
# Column: int_itm_n_avg
# Type: float64
# Sample unique values: [1.        0.        0.6666668 2.        0.5      ]
# ------------------------------
#
# Column: ses_mo_avg
# Type: float64
# Sample unique values: [ 0.         -1.19999976  0.54545449  0.59999988  1.19999976]
# ------------------------------
#
# Column: ses_mo_sd
# Type: float64
# Sample unique values: [0.         1.99999994 0.73854893 1.         0.81649658]
# ------------------------------
#
# Column: ses_ho_avg
# Type: float64
# Sample unique values: [-0.54193545 -0.05806451 -0.22521986 -0.44516126  1.10322574]
# ------------------------------
#
# Column: ses_ho_sd
# Type: float64
# Sample unique values: [ 1.02838194 -0.13828477  0.38517736  0.52838194  1.52838208]
# ------------------------------
#
# Column: ses_wknd_r
# Type: float64
# Sample unique values: [1.         2.         0.72727274 0.         0.66666668]
# ------------------------------
#
# Column: ses_len_avg
# Type: float64
# Sample unique values: [ 1.33540013 -0.05105152  0.48315742  0.19480182  3.38081942]
# ------------------------------
#
# Column: time_to_int
# Type: float64
# Sample unique values: [ 1.82531042 -0.07262069  0.85554913  0.17979311  2.09565533]
# ------------------------------
#
# Column: time_to_tran
# Type: float64
# Sample unique values: [ 0.        25.         8.875      4.8833334 26.409667 ]
# ------------------------------
#
# Column: int_cat1_n
# Type: float64
# Sample unique values: [0. 1. 3. 2.]
# ------------------------------
#
# Column: int_cat2_n
# Type: float64
# Sample unique values: [0. 4. 1. 3. 2.]
# ------------------------------
#
# Column: int_cat3_n
# Type: float64
# Sample unique values: [0. 1.]
# ------------------------------
#
# Column: int_cat4_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat5_n
# Type: float64
# Sample unique values: [0. 1. 2.]
# ------------------------------
#
# Column: int_cat6_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat7_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat8_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat9_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat10_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat11_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat12_n
# Type: float64
# Sample unique values: [0. 1. 2. 3. 4.]
# ------------------------------
#
# Column: int_cat13_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat15_n
# Type: float64
# Sample unique values: [0.]
# ------------------------------
#
# Column: int_cat16_n
# Type: float64
# Sample unique values: [ 0.  2.  3. 10. 15.]
# ------------------------------
#
# Column: int_cat17_n
# Type: float64
# Sample unique values: [ 0. 13.  1.  3.  5.]
# ------------------------------
#
# Column: int_cat18_n
# Type: float64
# Sample unique values: [0. 3. 1. 8. 6.]
# ------------------------------
#
# Column: int_cat19_n
# Type: float64
# Sample unique values: [0. 3. 2. 1. 4.]
# ------------------------------
#
# Column: int_cat20_n
# Type: float64
# Sample unique values: [3. 0. 1. 2. 8.]
# ------------------------------
#
# Column: int_cat21_n
# Type: float64
# Sample unique values: [0. 1. 8. 2. 5.]
# ------------------------------
#
# Column: int_cat22_n
# Type: float64
# Sample unique values: [0.  0.5 6.5 1.  2. ]
# ------------------------------
#
# Column: int_cat23_n
# Type: float64
# Sample unique values: [0. 1.]
# ------------------------------
#
# Column: int_cat24_n
# Type: float64
# Sample unique values: [0. 1. 3. 2.]
# ------------------------------
#
# Column: target_class
# Type: int64
# Sample unique values: [1 0]
# ------------------------------
#
# Column: engagement_ratio
# Type: float64
# Sample unique values: [ 0.25       -0.25       -0.06818182  0.75        2.        ]
# ------------------------------
#
# Column: conversion_rate
# Type: float64
# Sample unique values: [0.         0.125      0.2        0.05555556 0.04081633]
# ------------------------------
#
# Column: avg_items_per_interaction
# Type: float64
# Sample unique values: [1.        0.        0.6666668 2.        0.5      ]
# ------------------------------
#
# Column: session_consistency
# Type: float64
# Sample unique values: [ 0.         -1.56581175 -1.31189627 -1.56287304 -0.28996513]
# ------------------------------
#
# Column: weekend_preference
# Type: float64
# Sample unique values: [0. 1.]
# ------------------------------
#
# Column: category_diversity
# Type: float64
# Sample unique values: [0. 1. 2. 3.]
# ------------------------------
#
# Column: avg_transaction_value
# Type: float64
# Sample unique values: [    0. 41400. 23760. 43080. 29400.]
# ------------------------------
#
# Column: value_segment
# Type: object
# Sample unique values: ['No Purchase' 'Low' 'Medium' 'High']
# ------------------------------
#
# Column: recency_score
# Type: float64
# Sample unique values: [-0.20588235  0.09411765  0.29411765  0.         -0.16042781]
# ------------------------------
#
# Column: user_lifetime
# Type: float64
# Sample unique values: [ 0.43333333  1.96666667 -0.16666667 -0.06666667  0.56666667]
# ------------------------------
#
# Column: activity_regularity
# Type: float64
# Sample unique values: [ 0.         -1.92435882 -1.34193131 -1.28290588 -2.14511926]
# ------------------------------
#
# Column: peak_hour_activity
# Type: bool
# Sample unique values: [ True False]
# ------------------------------
#
# Column: recency_segment
# Type: object
# Sample unique values: ['Moderate' 'Recent' 'Old' 'Very Recent']
# ------------------------------
#
# Column: activity_decline
# Type: bool
# Sample unique values: [ True False]
# ------------------------------
#
# Column: low_engagement
# Type: bool
# Sample unique values: [False  True]
# ------------------------------
#
# Column: recency_risk
# Type: float64
# Sample unique values: [ 0.4375 -0.125  -0.3125  0.      0.3125]
# ------------------------------
#
# Column: engagement_risk
# Type: float64
# Sample unique values: [-0.25        0.25        0.06818182 -0.75       -2.        ]
# ------------------------------
#
# Column: value_risk
# Type: float64
# Sample unique values: [ 0.         -0.00069326 -0.00079574 -0.00072139 -0.00049231]
# ------------------------------
#
# Column: churn_risk_score
# Type: float64
# Sample unique values: [ 0.43048666  0.44295482 -0.1310924  -0.34133262  0.        ]
# ------------------------------
#
# Column: risk_segment
# Type: object
# Sample unique values: ['High' 'Medium' 'Low' 'Very High' 'Very Low']
# ------------------------------
#
# Numeric columns statistics:
# ==================================================
#           visitorid       ses_rec   ses_rec_avg    ses_rec_sd    ses_rec_cv  \
# count  4.935800e+04  49358.000000  49358.000000  49358.000000  49358.000000
# mean   7.072986e+05     -0.034072      0.625693      2.665237     -0.017550
# std    4.072098e+05      0.574040      1.256024      6.345187      0.538690
# min    3.700000e+01     -1.000000     -0.157895      0.000000     -0.610260
# 25%    3.532920e+05     -0.562500     -0.157895      0.000000     -0.610260
# 50%    7.100910e+05      0.000000      0.000000      0.000000      0.000000
# 75%    1.060355e+06      0.437500      0.842105      1.000000      0.389740
# max    1.407573e+06      0.937500      5.385965     32.000000      1.467071
#
#            user_rec         ses_n       ses_n_r         int_n       int_n_r  \
# count  49358.000000  49358.000000  49358.000000  49358.000000  49358.000000
# mean       0.260398      1.071032      0.710372      0.633565      0.436816
# std        0.840326      2.498491      2.915288      1.758437      1.178296
# min       -0.866667      0.000000    -10.285714     -0.250000     -0.250000
# 25%       -0.333333      0.000000     -0.285714     -0.250000     -0.250000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.666667      1.000000      0.714286      0.750000      0.750000
# max        2.366667     17.000000     18.000000     11.500000      6.416666
#
#        ...  weekend_preference  category_diversity  avg_transaction_value  \
# count  ...        49358.000000        49358.000000           49358.000000
# mean   ...            0.178249            0.347988            2873.838413
# std    ...            0.382726            0.629536           17351.266250
# min    ...            0.000000            0.000000               0.000000
# 25%    ...            0.000000            0.000000               0.000000
# 50%    ...            0.000000            0.000000               0.000000
# 75%    ...            0.000000            1.000000               0.000000
# max    ...            1.000000            3.000000          142320.000000
#
#        recency_score  user_lifetime  activity_regularity  recency_risk  \
# count   49358.000000   49358.000000         49358.000000  49358.000000
# mean        0.964278       0.260398            -0.375618     -0.034072
# std         2.590142       0.840326             0.607622      0.574040
# min        -0.330882      -0.866667            -2.360959     -1.000000
# 25%        -0.205882      -0.333333            -1.000000     -0.562500
# 50%         0.000000       0.000000             0.000000      0.000000
# 75%         0.794118       0.666667             0.000000      0.437500
# max        11.294118       2.366667             0.000000      0.937500
#
#        engagement_risk   value_risk  churn_risk_score
# count     49358.000000  49358.00000      49358.000000
# mean         -0.470975     -0.00020         -0.052771
# std           1.455885      0.00582          0.582093
# min         -57.750000     -1.00000         -2.750083
# 25%          -0.750000      0.00000         -0.569513
# 50%           0.000000      0.00000          0.000000
# 75%           0.250000      0.00000          0.430487
# max           0.250000      0.00000          0.949189
#
# [8 rows x 63 columns]

# %% [markdown]
# # Column Descriptions
#
# ## User Identification
# - `visitorid`: Unique identifier for each customer
#
# ## Session and Interaction Metrics
# - `ses_rec`: Recent session activity
# - `ses_n`: Number of sessions
# - `int_n`: Number of interactions
# - `tran_n`: Number of transactions
# - `rev_sum`: Total revenue/purchase amount
#
# ## Time-based Metrics
# - `time_to_int`: Time to interaction
# - `time_to_tran`: Time to transaction
# - `user_lifetime`: Customer's lifetime with the platform
#
# ## Engagement Metrics
# - `engagement_ratio`: User engagement score
# - `conversion_rate`: Conversion rate for the user
# - `avg_items_per_interaction`: Average items per interaction
# - `session_consistency`: Consistency of user sessions
# - `weekend_preference`: Preference for weekend activity
#
# ## Value and Risk Metrics
# - `avg_transaction_value`: Average value per transaction
# - `value_segment`: Customer value segment (Low, Medium, High)
# - `churn_risk_score`: Probability of customer churning
# - `risk_segment`: Risk categorization (Low, Medium, High, Very High)
#
# ## Behavioral Metrics
# - `category_diversity`: Diversity in category interactions
# - `activity_regularity`: Regularity of user activity
# - `peak_hour_activity`: Activity during peak hours
# - `activity_decline`: Whether activity is declining
#
# ## Target Variable
# - `target_class`: Churn status (1 for churned, 0 for not churned)
#
# ## Category Interaction Counts
# - `int_cat1_n` through `int_cat24_n`: Interaction counts for different product categories

# %%
import pandas as pd
import numpy as np

# Load the preprocessed data
df = pd.read_csv('../data/processed/preprocessed_churn_data.csv')

# Create a structured summary of columns
def get_column_groups():
    column_groups = {
        'Session Metrics': [
            'ses_rec', 'ses_rec_avg', 'ses_rec_sd', 'ses_rec_cv',
            'ses_n', 'ses_n_r',
            'ses_mo_avg', 'ses_mo_sd',
            'ses_ho_avg', 'ses_ho_sd',
            'ses_wknd_r',
            'ses_len_avg'
        ],
        'User Metrics': [
            'visitorid',
            'user_rec',
            'user_lifetime'
        ],
        'Interaction Metrics': [
            'int_n', 'int_n_r',
            'int_cat_n_avg', 'int_itm_n_avg'
        ],
        'Transaction Metrics': [
            'tran_n', 'tran_n_r',
            'rev_sum', 'rev_sum_r',
            'major_spend_r'
        ],
        'Time Metrics': [
            'time_to_int',
            'time_to_tran'
        ],
        'Category Interactions': [
            'int_cat1_n', 'int_cat2_n', 'int_cat3_n', 'int_cat4_n',
            'int_cat5_n', 'int_cat6_n', 'int_cat7_n', 'int_cat8_n',
            'int_cat9_n', 'int_cat10_n', 'int_cat11_n', 'int_cat12_n',
            'int_cat13_n', 'int_cat15_n', 'int_cat16_n', 'int_cat17_n',
            'int_cat18_n', 'int_cat19_n', 'int_cat20_n', 'int_cat21_n',
            'int_cat22_n', 'int_cat23_n', 'int_cat24_n'
        ],
        'Engagement and Behavioral': [
            'engagement_ratio',
            'conversion_rate',
            'avg_items_per_interaction',
            'session_consistency',
            'weekend_preference',
            'category_diversity',
            'avg_transaction_value'
        ],
        'Segments and Risk': [
            'value_segment',
            'recency_score',
            'recency_segment',
            'activity_regularity',
            'peak_hour_activity',
            'activity_decline',
            'low_engagement',
            'recency_risk',
            'engagement_risk',
            'value_risk',
            'churn_risk_score',
            'risk_segment'
        ],
        'Target': [
            'target_class'
        ]
    }
    return column_groups

# Get column groups
column_groups = get_column_groups()

# Print summary
print("COMPLETE COLUMN SUMMARY")
print("=" * 50)
print(f"Total number of columns: {len(df.columns)}")
print("\nBreakdown by category:")
print("-" * 30)

for category, cols in column_groups.items():
    print(f"\n{category} ({len(cols)} columns):")
    for col in cols:
        if col in df.columns:
            dtype = str(df[col].dtype)
            sample = str(df[col].iloc[0])[:50]  # Truncate long values
            print(f"  - {col:<25} | Type: {dtype:<15} | Example: {sample}")
        else:
            print(f"  - {col:<25} | Not found in dataset")
        
# Verify all columns are accounted for
all_grouped_cols = [col for cols in column_groups.values() for col in cols]
missing_cols = set(df.columns) - set(all_grouped_cols)
extra_cols = set(all_grouped_cols) - set(df.columns)

if missing_cols:
    print("\nWarning: Following columns are not categorized:")
    for col in sorted(missing_cols):
        dtype = str(df[col].dtype)
        sample = str(df[col].iloc[0])[:50]
        print(f"  - {col:<25} | Type: {dtype:<15} | Example: {sample}")
        
if extra_cols:
    print("\nWarning: Following categorized columns are not in dataset:")
    for col in sorted(extra_cols):
        print(f"  - {col}")
# Out:
# COMPLETE COLUMN SUMMARY
# ==================================================
# Total number of columns: 69
#
# Breakdown by category:
# ------------------------------
#
# Session Metrics (12 columns):
#   - ses_rec                   | Type: float64         | Example: 0.4375
#   - ses_rec_avg               | Type: float64         | Example: 0.9649122807017544
#   - ses_rec_sd                | Type: float64         | Example: 0.0
#   - ses_rec_cv                | Type: float64         | Example: 0.0
#   - ses_n                     | Type: float64         | Example: 0.0
#   - ses_n_r                   | Type: float64         | Example: -0.3736263514536896
#   - ses_mo_avg                | Type: float64         | Example: 0.0
#   - ses_mo_sd                 | Type: float64         | Example: 0.0
#   - ses_ho_avg                | Type: float64         | Example: -0.5419354489073905
#   - ses_ho_sd                 | Type: float64         | Example: 1.0283819382372748
#   - ses_wknd_r                | Type: float64         | Example: 1.0
#   - ses_len_avg               | Type: float64         | Example: 1.3354001329784502
#
# User Metrics (3 columns):
#   - visitorid                 | Type: int64           | Example: 89
#   - user_rec                  | Type: float64         | Example: 0.4333333333333333
#   - user_lifetime             | Type: float64         | Example: 0.4333333333333333
#
# Interaction Metrics (4 columns):
#   - int_n                     | Type: float64         | Example: 0.0
#   - int_n_r                   | Type: float64         | Example: 0.25
#   - int_cat_n_avg             | Type: float64         | Example: 0.0
#   - int_itm_n_avg             | Type: float64         | Example: 1.0
#
# Transaction Metrics (5 columns):
#   - tran_n                    | Type: float64         | Example: 0.0
#   - tran_n_r                  | Type: float64         | Example: 0.0
#   - rev_sum                   | Type: float64         | Example: 0.0
#   - rev_sum_r                 | Type: float64         | Example: 0.0
#   - major_spend_r             | Type: float64         | Example: 0.0
#
# Time Metrics (2 columns):
#   - time_to_int               | Type: float64         | Example: 1.825310417337839
#   - time_to_tran              | Type: float64         | Example: 0.0
#
# Category Interactions (23 columns):
#   - int_cat1_n                | Type: float64         | Example: 0.0
#   - int_cat2_n                | Type: float64         | Example: 0.0
#   - int_cat3_n                | Type: float64         | Example: 0.0
#   - int_cat4_n                | Type: float64         | Example: 0.0
#   - int_cat5_n                | Type: float64         | Example: 0.0
#   - int_cat6_n                | Type: float64         | Example: 0.0
#   - int_cat7_n                | Type: float64         | Example: 0.0
#   - int_cat8_n                | Type: float64         | Example: 0.0
#   - int_cat9_n                | Type: float64         | Example: 0.0
#   - int_cat10_n               | Type: float64         | Example: 0.0
#   - int_cat11_n               | Type: float64         | Example: 0.0
#   - int_cat12_n               | Type: float64         | Example: 0.0
#   - int_cat13_n               | Type: float64         | Example: 0.0
#   - int_cat15_n               | Type: float64         | Example: 0.0
#   - int_cat16_n               | Type: float64         | Example: 0.0
#   - int_cat17_n               | Type: float64         | Example: 0.0
#   - int_cat18_n               | Type: float64         | Example: 0.0
#   - int_cat19_n               | Type: float64         | Example: 0.0
#   - int_cat20_n               | Type: float64         | Example: 3.0
#   - int_cat21_n               | Type: float64         | Example: 0.0
#   - int_cat22_n               | Type: float64         | Example: 0.0
#   - int_cat23_n               | Type: float64         | Example: 0.0
#   - int_cat24_n               | Type: float64         | Example: 0.0
#
# Engagement and Behavioral (7 columns):
#   - engagement_ratio          | Type: float64         | Example: 0.25
#   - conversion_rate           | Type: float64         | Example: 0.0
#   - avg_items_per_interaction | Type: float64         | Example: 1.0
#   - session_consistency       | Type: float64         | Example: 0.0
#   - weekend_preference        | Type: float64         | Example: 0.0
#   - category_diversity        | Type: float64         | Example: 0.0
#   - avg_transaction_value     | Type: float64         | Example: 0.0
#
# Segments and Risk (12 columns):
#   - value_segment             | Type: object          | Example: No Purchase
#   - recency_score             | Type: float64         | Example: -0.2058823529411764
#   - recency_segment           | Type: object          | Example: Moderate
#   - activity_regularity       | Type: float64         | Example: 0.0
#   - peak_hour_activity        | Type: bool            | Example: True
#   - activity_decline          | Type: bool            | Example: True
#   - low_engagement            | Type: bool            | Example: False
#   - recency_risk              | Type: float64         | Example: 0.4375
#   - engagement_risk           | Type: float64         | Example: -0.2500000000000049
#   - value_risk                | Type: float64         | Example: 0.0
#   - churn_risk_score          | Type: float64         | Example: 0.4304866604102432
#   - risk_segment              | Type: object          | Example: High
#
# Target (1 columns):
#   - target_class              | Type: int64           | Example: 1
